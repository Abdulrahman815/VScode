# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
sns.set()

# %%
raw_data = pd.read_csv(r'C:/Users/ASUS/Desktop/Subjects/DataSets/1.04. Real-life example.csv')
raw_data.head()
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
# 4         Toyota  18300.0  crossover      120      2.0      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4

# %%
df = raw_data.copy()
df = df.dropna(axis = 0)

# %%
q = df['Price'].quantile(0.99)
print(q)
df['Price'] = df['Price'][df['Price'] < q]
sns.boxplot(df['Price'])
# Out:
# 129812.51999999981
# <Axes: >

# %%
df.describe(include = 'all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4025    3984.000000   4025  4025.000000  4025.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1534          NaN          NaN
# mean           NaN   17837.117460    NaN   163.572174     2.764586
# std            NaN   18976.268315    NaN   103.394703     4.935941
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6980.000000    NaN    90.000000     1.800000
# 50%            NaN   11400.000000    NaN   158.000000     2.200000
# 75%            NaN   21000.000000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4025         4025  4025.000000     4025
# ...

# %%
sns.boxplot(df['Mileage'])
print(df['Mileage'].quantile(0.999))
# Out:
# 649.5200000000114

# %%
q = df['Mileage'].quantile(0.999)
df['Mileage'] = df['Mileage'][df['Mileage'] < q]
sns.boxplot(df['Mileage'])
# Out:
# <Axes: >

# %%
df = df[df['EngineV'] < 6.5]
df.describe()
# Out:
#                Price      Mileage      EngineV         Year
# count    3961.000000  3997.000000  4002.000000  4002.000000
# mean    17890.545307   162.615211     2.466724  2006.395302
# std     19009.523529   101.137668     0.973586     6.696077
# min       600.000000     0.000000     0.600000  1969.000000
# 25%      6999.000000    90.000000     1.800000  2003.000000
# 50%     11500.000000   157.000000     2.200000  2008.000000
# 75%     21200.000000   230.000000     3.000000  2012.000000
# max    129222.000000   630.000000     6.300000  2016.000000

# %%
q = df['Year'].quantile(0.01)
df = df[df['Year'] > q]
sns.displot(df['Year'])

# %%
df = df.reset_index(drop= True)
df = df.drop(['Model'], axis = 1)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey = True, figsize=[15,3])
ax1.scatter(df['Year'], df['Price'])
ax1.set_title("Log-Price vs. Year")
ax2.scatter(df['EngineV'], df['Price'])
ax2.set_title("Log-Price vs. Engine volume")
ax3.scatter(df['Mileage'], df['Price'])
ax3.set_title("Log-Price vs. Mileage")
# Out:
# Text(0.5, 1.0, 'Log-Price vs. Mileage')

# %%
df['Price'] = np.log(df['Price'])

# %%
df = df.dropna(axis= 0)
df.isnull().sum()
# Out:
# Brand           0
# Price           0
# Body            0
# Mileage         0
# EngineV         0
# Engine Type     0
# Registration    0
# Year            0
# dtype: int64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = df[['Mileage', 'Year', 'EngineV']]   
vif = pd.DataFrame()

vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]

# %%
vif
# Out:
#          VIF
# 0   3.644120
# 1  10.263057
# 2   7.681051

# %%
df_with_dummies = pd.get_dummies(df, drop_first = True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables1 = df_with_dummies.drop(['Price'],axis = 1)
vif1 = pd.DataFrame()
vif1['Features'] = df_with_dummies.columns[1:]
vif1["VIF"] = [variance_inflation_factor(variables1.values, i) for i in range(variables1.shape[1])]

# %%
vif1
# Out:
#                Features        VIF
# 0               Mileage   4.575970
# 1               EngineV  12.083715
# 2                  Year  44.090445
# 3             Brand_BMW   2.612104
# 4   Brand_Mercedes-Benz   3.117370
# 5      Brand_Mitsubishi   1.948306
# 6         Brand_Renault   2.446399
# 7          Brand_Toyota   2.471407
# 8      Brand_Volkswagen   3.480715
# 9            Body_hatch   1.680138
# 10           Body_other   1.665188
# 11           Body_sedan   3.753191
# 12           Body_vagon   1.932219
# 13             Body_van   2.694802
# 14      Engine Type_Gas   1.684268
# 15    Engine Type_Other   1.082424
# 16   Engine Type_Petrol   2.487365
# 17     Registration_yes  12.546687

# %%
df = df_with_dummies.drop(['Registration_yes'], axis= 1)
targets = df['Price']
inputs = df.drop(['Price'], axis = 1)
targets.describe()
# Out:
# count    3900.000000
# mean        9.407463
# std         0.878760
# min         6.684612
# 25%         8.873113
# 50%         9.350102
# 75%         9.975808
# max        11.769287
# Name: Price, dtype: float64

# %%
import statsmodels.api as sm 
x = sm.add_constant(inputs)
reg1 = sm.OLS(targets,x).fit()
reg1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                     999.1
# Date:                Sun, 13 Aug 2023   Prob (F-statistic):               0.00
# Time:                        19:33:04   Log-Likelihood:                -1749.8
# No. Observations:                3900   AIC:                             3536.
# Df Residuals:                    3882   BIC:                             3648.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(inputs)
inputs_scaled = scaler.transform(inputs)
scaler.get_params()
# Out:
# {'copy': True, 'with_mean': True, 'with_std': True}

# %%
df.columns.values
# Out:
# array(['Price', 'Mileage', 'EngineV', 'Year', 'Brand_BMW',
#        'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
#        'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
#        'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
#        'Engine Type_Other', 'Engine Type_Petrol'], dtype=object)

# %%
check = pd.DataFrame(inputs)
check['output'] = targets
corr = check.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
inputs_scaled.shape
# Out:
# (3900, 17)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
reg.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
yhat = reg.predict(x_train)

plt.scatter(y_train, yhat)

# %%
reg.score(x_train, y_train)
# Out:
# 0.8091509124567248

# %%
sns.distplot(y_train - yhat)
print(len(inputs.columns.values))
print(len(reg.coef_))
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21644\3958350895.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train - yhat)
# 18
# 17

# %%
reg_summary = pd.DataFrame(data = inputs.columns.values, columns = ['Features'])
reg_summary['Coefficiants'] = reg.coef_
reg_summary
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 reg_summary = pd.DataFrame(data = inputs.columns.values, columns = ['Features'])
# ----> 2 reg_summary['Coefficiants'] = reg.coef_
#       3 reg_summary
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
# ...

# %%
yhat_test = reg.predict(x_test)

# %%
plt.scatter(y_test, yhat_test,alpha = 0.2)

# %%
reg.score(x_train, y_train)

# %%
predic = reg.predict(x_test)

# %%
y_test

# %%
r_adj = 1 - (1-reg.score(x_test,y_test)) * ((x.shape[0]-1)/(x.shape[0]-x.shape[1] - 1))
print(r_adj)
# Out:
# 0.8312311422911398

# %%
print(reg1.)
# Out:
# 2450.7302586919905

# %%
metric = pd.DataFrame(['Score/R-squared', 'Adjusted R-squared', 'Durbin-Watson', 'F-statistic'],columns =['Model Metric'])
metric['Values'] = reg.score(x_test, y_test), r_adj, 2.024, reg1.fvalue

# %%
metric
# Out:
#          Model Metric      Values
# 0     Score/R-squared    0.832010
# 1  Adjusted R-squared    0.831231
# 2       Durbin-Watson    2.024000
# 3         F-statistic  999.075537
